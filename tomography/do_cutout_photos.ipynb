# %%
from importlib import reload
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
import imageio
import os
from skimage import color, io
import skimage
from importlib import reload
from matplotlib import rc
import cv2
rc('image', origin='lower')

# %%
import cutout_photos
reload(cutout_photos)
# Out:
# <module 'cutout_photos' from '/Users/jesse/Code/cigar-research/tomography/cutout_photos.py'>

# %%
cutout = cutout_photos.generate_cutout((3, 'v', 1), 0.3, 50, 50)

# %%
plt.imshow(cutout)
plt.show()

# %%
ph_ids = cutout_photos.get_valid_photo_ids()

for ph_id in ph_ids:
    print("Processing photo %s..." % str(ph_id), end='')
    cutout_photos.generate_cutout(ph_id, 0.3, 50, 50)
    print("done!")
# Out:
# Processing photo (1, 'a', 1)...done!
# Processing photo (1, 'a', 2)...done!
# Processing photo (1, 'a', 3)...done!
# Processing photo (1, 'v', 1)...done!
# Processing photo (1, 'v', 2)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-ac63cbf917dd> in <module>()
#       3 for ph_id in ph_ids:
#       4     print("Processing photo %s..." % str(ph_id), end='')
# ----> 5     cutout_photos.generate_cutout(ph_id, 0.3, 50, 50)
#       6     print("done!")
#
# ~/Code/cigar-research/tomography/cutout_photos.py in generate_cutout(ph_id, th, closing_size, opening_size, th_below)
#      50 def generate_cutout(ph_id, th, closing_size, opening_size, th_below=True):
#      51     orig_img = io.imread(photo_fn_format % ph_id)[::-1, :, :]
# ---> 52     gscale_img = color.rgb2gray(orig_img)
#      53     red_img = orig_img[:, :, 0]
#      54     grn_img = orig_img[:, :, 1]
# ...
