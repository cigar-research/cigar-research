# %%
from importlib import reload
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
import imageio
import os
from skimage import color, io
import skimage
from importlib import reload
from matplotlib import rc
import cv2
rc('image', origin='lower')

# %%
import cutout_photos
reload(cutout_photos)
# Out:
# <module 'cutout_photos' from 'Z:\\projects\\cigar\\git-repository\\tomography\\cutout_photos.py'>

# %%
cutout = cutout_photos.generate_cutout((3, 'v', 1), 0.3, 50, 50)

# %%
plt.imshow(cutout)
plt.show()

# %%
ph_ids = cutout_photos.get_valid_photo_ids()

for ph_id in ph_ids:
    print("Processing photo %s..." % str(ph_id), end='')
    cutout_photos.generate_cutout(ph_id, 0.3, 50, 50)
    print("done!")
# Out:
# Processing photo (1, 'a', 1)...done!
# Processing photo (1, 'a', 2)...done!
# Processing photo (1, 'a', 3)...done!
# Processing photo (1, 'v', 1)...done!
# Processing photo (1, 'v', 2)...done!
# Processing photo (1, 'v', 3)...done!
# Processing photo (2, 'a', 1)...done!
# Processing photo (2, 'a', 2)...done!
# Processing photo (2, 'a', 3)...done!
# Processing photo (2, 'v', 1)...done!
# Processing photo (2, 'v', 2)...done!
# Processing photo (2, 'v', 3)...done!
# Processing photo (3, 'a', 1)...done!
# Processing photo (3, 'a', 2)...done!
# Processing photo (3, 'a', 3)...done!
# Processing photo (3, 'v', 1)...done!
# Processing photo (3, 'v', 2)...done!
# Processing photo (3, 'v', 3)...done!
# Processing photo (4, 'a', 1)...done!
# Processing photo (4, 'a', 2)...done!
# Processing photo (4, 'a', 3)...done!
# Processing photo (4, 'v', 1)...done!
# Processing photo (4, 'v', 2)...done!
# Processing photo (4, 'v', 3)...done!
# Processing photo (5, 'a', 1)...done!
# Processing photo (5, 'a', 2)...done!
# Processing photo (5, 'a', 3)...done!
# Processing photo (5, 'v', 1)...done!
# Processing photo (5, 'v', 2)...done!
# Processing photo (5, 'v', 3)...done!
# Processing photo (5, 'v', 4)...done!
# Processing photo (6, 'a', 1)...done!
# Processing photo (6, 'a', 2)...done!
# Processing photo (6, 'a', 3)...done!
# Processing photo (6, 'v', 1)...done!
# Processing photo (6, 'v', 2)...done!
# Processing photo (6, 'v', 3)...done!
# Processing photo (7, 'a', 1)...done!
# Processing photo (7, 'a', 2)...done!
# Processing photo (7, 'a', 3)...done!
# Processing photo (7, 'a', 4)...done!
# Processing photo (7, 'v', 1)...done!
# Processing photo (7, 'v', 2)...done!
# Processing photo (7, 'v', 3)...done!
# Processing photo (7, 'v', 4)...done!
# Processing photo (8, 'a', 1)...done!
# Processing photo (8, 'a', 2)...done!
# Processing photo (8, 'a', 3)...done!
# Processing photo (8, 'a', 4)...done!
# Processing photo (8, 'a', 5)...done!
# Processing photo (8, 'v', 1)...done!
# Processing photo (8, 'v', 2)...done!
# Processing photo (8, 'v', 3)...done!
# Processing photo (8, 'v', 4)...done!
# Processing photo (9, 'a', 1)...done!
# Processing photo (9, 'a', 2)...done!
# Processing photo (9, 'a', 3)...done!
# Processing photo (9, 'a', 4)...done!
# Processing photo (9, 'v', 1)...done!
# Processing photo (9, 'v', 2)...done!
# Processing photo (9, 'v', 3)...done!
# Processing photo (10, 'a', 1)...done!
# Processing photo (10, 'a', 2)...done!
# Processing photo (10, 'a', 3)...done!
# Processing photo (10, 'a', 4)...done!
# Processing photo (10, 'v', 1)...done!
# Processing photo (10, 'v', 2)...done!
# Processing photo (10, 'v', 3)...done!
# Processing photo (11, 'a', 1)...done!
# Processing photo (11, 'a', 2)...done!
# Processing photo (11, 'a', 3)...done!
# Processing photo (11, 'a', 4)...done!
# Processing photo (11, 'v', 1)...done!
# Processing photo (11, 'v', 2)...done!
# Processing photo (11, 'v', 3)...done!
# Processing photo (12, 'a', 1)...done!
# Processing photo (12, 'a', 2)...done!
# Processing photo (12, 'a', 3)...done!
# Processing photo (12, 'a', 4)...done!
# Processing photo (12, 'v', 1)...done!
# Processing photo (12, 'v', 2)...done!
# Processing photo (12, 'v', 3)...done!
# Processing photo (12, 'v', 4)...done!
# Processing photo (12, 'v', 5)...done!
# Processing photo (13, 'a', 1)...done!
# Processing photo (13, 'a', 2)...done!
# Processing photo (13, 'a', 3)...done!
# Processing photo (13, 'a', 4)...done!
# Processing photo (13, 'a', 5)...done!
# Processing photo (13, 'v', 1)...done!
# Processing photo (13, 'v', 2)...done!
# Processing photo (13, 'v', 3)...done!
# Processing photo (13, 'v', 4)...done!
# Processing photo (14, 'a', 1)...done!
# Processing photo (14, 'a', 2)...done!
# Processing photo (14, 'a', 3)...done!
# Processing photo (14, 'a', 4)...done!
# Processing photo (14, 'v', 1)...done!
# Processing photo (14, 'v', 2)...done!
# Processing photo (14, 'v', 3)...done!
# Processing photo (14, 'v', 4)...done!
# Processing photo (15, 'a', 1)...done!
# Processing photo (15, 'a', 2)...done!
# Processing photo (15, 'a', 3)...done!
# Processing photo (15, 'a', 4)...done!
# Processing photo (15, 'v', 1)...done!
# Processing photo (15, 'v', 2)...done!
# Processing photo (15, 'v', 3)...done!
# Processing photo (15, 'v', 4)...done!
# Processing photo (16, 'a', 1)...done!
# Processing photo (16, 'a', 2)...done!
# Processing photo (16, 'a', 3)...done!
# Processing photo (16, 'a', 4)...done!
# Processing photo (16, 'a', 5)...done!
# Processing photo (16, 'v', 1)...done!
# Processing photo (16, 'v', 2)...done!
# Processing photo (16, 'v', 3)...done!
# Processing photo (16, 'v', 4)...done!
# Processing photo (17, 'a', 1)...done!
# Processing photo (17, 'a', 2)...done!
# Processing photo (17, 'a', 3)...done!
# Processing photo (17, 'a', 4)...done!
# Processing photo (17, 'a', 5)...done!
# Processing photo (17, 'a', 6)...done!
# Processing photo (17, 'v', 1)...done!
# Processing photo (17, 'v', 2)...done!
# Processing photo (17, 'v', 3)...done!
# Processing photo (17, 'v', 4)...done!
# Processing photo (17, 'v', 5)...done!
# Processing photo (18, 'a', 1)...done!
# Processing photo (18, 'a', 2)...done!
# Processing photo (18, 'a', 3)...done!
# Processing photo (18, 'a', 4)...done!
# Processing photo (18, 'a', 5)...done!
# Processing photo (18, 'v', 1)...done!
# Processing photo (18, 'v', 2)...done!
# Processing photo (18, 'v', 3)...done!
# Processing photo (18, 'v', 4)...done!
# Processing photo (19, 'a', 1)...done!
# Processing photo (19, 'a', 2)...done!
# Processing photo (19, 'a', 3)...done!
# Processing photo (19, 'a', 4)...done!
# Processing photo (19, 'a', 5)...done!
# Processing photo (19, 'a', 6)...done!
# Processing photo (19, 'v', 1)...done!
# Processing photo (19, 'v', 2)...done!
# Processing photo (19, 'v', 3)...done!
# Processing photo (19, 'v', 4)...done!
# Processing photo (20, 'a', 1)...done!
# Processing photo (20, 'a', 2)...done!
# Processing photo (20, 'a', 3)...done!
# Processing photo (20, 'v', 1)...done!
# Processing photo (20, 'v', 2)...done!
# Processing photo (20, 'v', 3)...done!
# Processing photo (20, 'v', 4)...done!
# Processing photo (20, 'v', 5)...done!
# Processing photo (21, 'a', 1)...done!
# Processing photo (21, 'a', 2)...done!
# Processing photo (21, 'a', 3)...done!
# Processing photo (21, 'a', 4)...done!
# Processing photo (21, 'v', 1)...done!
# Processing photo (21, 'v', 2)...done!
# Processing photo (21, 'v', 3)...done!
# Processing photo (21, 'v', 4)...done!
# Processing photo (22, 'a', 1)...done!
# Processing photo (22, 'a', 2)...done!
# Processing photo (22, 'a', 3)...done!
# Processing photo (22, 'a', 4)...done!
# Processing photo (22, 'v', 1)...done!
# Processing photo (22, 'v', 2)...done!
# Processing photo (22, 'v', 3)...done!
# Processing photo (22, 'v', 4)...done!
# Processing photo (23, 'a', 1)...done!
# Processing photo (23, 'a', 2)...done!
# Processing photo (23, 'a', 3)...done!
# Processing photo (23, 'a', 4)...done!
# Processing photo (23, 'a', 5)...done!
# Processing photo (23, 'a', 6)...done!
# Processing photo (23, 'v', 1)...done!
# Processing photo (23, 'v', 2)...done!
# Processing photo (23, 'v', 3)...done!
# Processing photo (23, 'v', 4)...done!
# Processing photo (24, 'a', 1)...done!
# Processing photo (24, 'a', 2)...done!
# Processing photo (24, 'a', 3)...done!
# Processing photo (24, 'a', 4)...done!
# Processing photo (24, 'a', 5)...done!
# Processing photo (24, 'v', 1)...done!
# Processing photo (24, 'v', 2)...done!
# Processing photo (24, 'v', 3)...done!
# Processing photo (24, 'v', 4)...done!
